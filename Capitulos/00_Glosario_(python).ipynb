# %% [markdown]
# <a href="https://colab.research.google.com/github/felipeandaurp-ai/Felipe/blob/main/00_Glosario_(python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Glosario
# 1. Division entera (`//`)
#
# >Es la division entre dos numero es cual el resultado es simpre entero por lo tanto se redondea al entero menos.
#
# ---
#
# 2. Expresion
#
# >Una colocacion de operadores y numeros
#
# ---
#
# 3. el valor
#
# >Es el resultado de una expresion
#
# ---
#
# 4. error SyntaxError
#
# >Ocurre cuando llamo una funcion y cometo un error en su escritura(por ejemplo: abs 42, es un error pues no tiene parentesis)
#
# ---
#
# 5. función `len`
#
# >Cuenta la cantidad de caracteres que tiene un string. Si no pongo los parentesis tengo un error de sintaxis
#
# ---
#
# 6. Error de tipo (typeError)
#
# >Cuando se ejecuta una operacion que no esta asociada a un tipo (ejemplo: dividir un String pues con el solo puedo * y +)
#
# ---
#
# 7. Debugging
# > es el proceso de encontrar y corregir errores
